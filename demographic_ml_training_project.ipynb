# %% [markdown]
# # demographic model training

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv(r'C:\Users\lenovo\OneDrive\Documents\hacktho\notebook\karnataka_aadhar_demographic.csv')

df.columns = [ 'date', 'state', 'district', 'pincode', 'demo_age_5_17', 'demo_age_17_']
df = df.drop('index', axis=1, errors='ignore')
df['date'] = pd.to_datetime(df['date'], format='mixed', dayfirst=True)

# Single numeric column
df['date_encoded'] = df['date'].apply(lambda x: x.toordinal())

df
# Out:
#              date      state  district  pincode  demo_age_5_17  demo_age_17_  \
# 0      2025-11-02  Karnataka  Bagalkot   587101              1             2
# 1      2025-11-02  Karnataka  Bagalkot   587103              3             5
# 2      2025-11-02  Karnataka  Bagalkot   587112              0             1
# 3      2025-11-02  Karnataka  Bagalkot   587201              1             2
# 4      2025-11-02  Karnataka  Bagalkot   587203              4             2
# ...           ...        ...       ...      ...            ...           ...
# 111489 2025-10-31  Karnataka    Yadgir   585315              0             7
# 111490 2025-10-31  Karnataka    Yadgir   585319              2            10
# 111491 2025-10-31  Karnataka    yadgir   585201              0             2
# 111492 2025-10-31  Karnataka    yadgir   585221              0             2
# 111493 2025-10-31  Karnataka    yadgir   585323              0             2
#
#         date_encoded
# 0             739557
# 1             739557
# 2             739557
# 3             739557
# 4             739557
# ...              ...
# 111489        739555
# 111490        739555
# 111491        739555
# 111492        739555
# 111493        739555
#
# [111494 rows x 7 columns]

# %%
df = df.drop('date', axis=1)
df = df.drop('state', axis=1)


le_district = LabelEncoder()
df['district_label'] = le_district.fit_transform(df['district'])
df
# Out:
#         district  pincode  demo_age_5_17  demo_age_17_  date_encoded  \
# 0       Bagalkot   587101              1             2        739557
# 1       Bagalkot   587103              3             5        739557
# 2       Bagalkot   587112              0             1        739557
# 3       Bagalkot   587201              1             2        739557
# 4       Bagalkot   587203              4             2        739557
# ...          ...      ...            ...           ...           ...
# 111489    Yadgir   585315              0             7        739555
# 111490    Yadgir   585319              2            10        739555
# 111491    yadgir   585201              0             2        739555
# 111492    yadgir   585221              0             2        739555
# 111493    yadgir   585323              0             2        739555
#
#         district_label
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 111489              53
# 111490              53
# 111491              54
# 111492              54
# 111493              54
#
# [111494 rows x 6 columns]

# %%
df_karnataka = df[df['district']=="Yadgir"]
print(len(df_karnataka))
df_karnataka
# Out:
# 1389
#        district  pincode  demo_age_5_17  demo_age_17_  date_encoded  \
# 263      Yadgir   585201              0             1        739557
# 264      Yadgir   585237              0             1        739557
# 265      Yadgir   585315              0             1        739557
# 621      Yadgir   585202              5            16        739558
# 622      Yadgir   585216             13            20        739558
# ...         ...      ...            ...           ...           ...
# 111486   Yadgir   585215             12            25        739555
# 111487   Yadgir   585216             13            14        739555
# 111488   Yadgir   585237              3            14        739555
# 111489   Yadgir   585315              0             7        739555
# 111490   Yadgir   585319              2            10        739555
#
#         district_label
# 263                 53
# 264                 53
# 265                 53
# 621                 53
# 622                 53
# ...                ...
# 111486              53
# 111487              53
# 111488              53
# 111489              53
# 111490              53
#
# [1389 rows x 6 columns]

# %%
y = df_karnataka[[ 'demo_age_5_17', 'demo_age_17_']]
y
# Out:
#         demo_age_5_17  demo_age_17_
# 263                 0             1
# 264                 0             1
# 265                 0             1
# 621                 5            16
# 622                13            20
# ...               ...           ...
# 111486             12            25
# 111487             13            14
# 111488              3            14
# 111489              0             7
# 111490              2            10
#
# [1389 rows x 2 columns]

# %%
avg_enrollments = df_karnataka[['demo_age_5_17', 'demo_age_17_']].mean(axis=1)

print(df_karnataka[['district', 'pincode', 'demo_age_5_17', 'demo_age_17_', 'avg_enrollments']].head())
# Out:
#     district  pincode  demo_age_5_17  demo_age_17_  avg_enrollments
# 263   Yadgir   585201              0             1              0.5
# 264   Yadgir   585237              0             1              0.5
# 265   Yadgir   585315              0             1              0.5
# 621   Yadgir   585202              5            16             10.5
# 622   Yadgir   585216             13            20             16.5

# %%
avg_child = df['demo_age_5_17'].mean()
avg_adult = df['demo_age_17_'].mean()

overall_avg = (df['demo_age_5_17'].sum() + df['demo_age_17_'].sum()) / (2 * len(df))

print(f"Average child enrollments: {avg_child:.2f}")
print(f"Average adult enrollments: {avg_adult:.2f}")
print(f"Overall average enrollment: {overall_avg:.2f}")
# Out:
# Average child enrollments: 1.59
# Average adult enrollments: 8.76
# Overall average enrollment: 5.17

# %% [markdown]
# # Demographic Averages by District + Pincode

# %%
grouped_avg = df_karnataka.groupby(['district', 'pincode'])[['demo_age_5_17', 'demo_age_17_']].mean().round(2)

grouped_avg['total_enrollments_avg'] = grouped_avg['demo_age_5_17'] + grouped_avg['demo_age_17_']
grouped_avg['overall_avg'] = grouped_avg[['demo_age_5_17', 'demo_age_17_']].mean(axis=1)
child_percentage = (grouped_avg['demo_age_5_17'] / grouped_avg['overall_avg'] * 100).round(1)

print(grouped_avg.sort_values('total_enrollments_avg', ascending=False).head(20))
# Out:
#                   demo_age_5_17  demo_age_17_  total_enrollments_avg  \
# district pincode
# Yadgir   585202           14.47         48.95                  63.42
#          585223            8.03         30.36                  38.39
#          585216            7.29         23.26                  30.55
#          585215            5.11         14.95                  20.06
#          585221            4.00         14.97                  18.97
#          585321            3.09         15.58                  18.67
#          585214            2.31         13.04                  15.35
#          585290            2.77         12.50                  15.27
#          585309            2.74         12.06                  14.80
#          585237            2.93          9.60                  12.53
#          585355            1.40          9.83                  11.23
#          585323            2.32          8.84                  11.16
#          585315            1.85          7.62                   9.47
#          585304            1.32          7.07                   8.39
#          585201            1.53          6.42                   7.95
#          585319            1.68          6.14                   7.82
#          585287            1.53          5.42                   6.95
#          585291            1.62          4.80                   6.42
#          585224            0.90          3.98                   4.88
#          585220            0.68          3.17                   3.85
#
#                   overall_avg
# district pincode
# Yadgir   585202        31.710
#          585223        19.195
#          585216        15.275
#          585215        10.030
#          585221         9.485
#          585321         9.335
#          585214         7.675
#          585290         7.635
#          585309         7.400
#          585237         6.265
#          585355         5.615
#          585323         5.580
#          585315         4.735
#          585304         4.195
#          585201         3.975
#          585319         3.910
#          585287         3.475
#          585291         3.210
#          585224         2.440
#          585220         1.925

# %%
A= df_karnataka.drop(['demo_age_5_17', 'demo_age_17_','district','avg_enrollments_per_row'],axis=1)
A
# Out:
#         pincode  date_encoded  district_label  avg_enrollments
# 263      585201        739557              53              0.5
# 264      585237        739557              53              0.5
# 265      585315        739557              53              0.5
# 621      585202        739558              53             10.5
# 622      585216        739558              53             16.5
# ...         ...           ...             ...              ...
# 111486   585215        739555              53             18.5
# 111487   585216        739555              53             13.5
# 111488   585237        739555              53              8.5
# 111489   585315        739555              53              3.5
# 111490   585319        739555              53              6.0
#
# [1389 rows x 4 columns]

# %%
# x = df_karnataka.drop(['district'],axis=1)
# x
# Out:
#         pincode  demo_age_5_17  demo_age_17_  date_encoded  district_label
# 263      585201              0             1        739557              52
# 264      585237              0             1        739557              52
# 265      585315              0             1        739557              52
# 621      585202              5            16        739558              52
# 622      585216             13            20        739558              52
# ...         ...            ...           ...           ...             ...
# 111486   585215             12            25        739555              52
# 111487   585216             13            14        739555              52
# 111488   585237              3            14        739555              52
# 111489   585315              0             7        739555              52
# 111490   585319              2            10        739555              52
#
# [1389 rows x 5 columns]

# %% [markdown]
# **DATA SPLITING**

# %%
features = [
    'district_label',
    'pincode',
    'demo_age_5_17',     # Child enrollments help predict adult
    'date_encoded',
    'avg_enrollments'

]

x = df_karnataka[features]
y = df_karnataka['demo_age_17_']

x
# Out:
#         district_label  pincode  demo_age_5_17  date_encoded  avg_enrollments
# 263                 53   585201              0        739557              0.5
# 264                 53   585237              0        739557              0.5
# 265                 53   585315              0        739557              0.5
# 621                 53   585202              5        739558             10.5
# 622                 53   585216             13        739558             16.5
# ...                ...      ...            ...           ...              ...
# 111486              53   585215             12        739555             18.5
# 111487              53   585216             13        739555             13.5
# 111488              53   585237              3        739555              8.5
# 111489              53   585315              0        739555              3.5
# 111490              53   585319              2        739555              6.0
#
# [1389 rows x 5 columns]

# %% [markdown]
#  **Train-Test Split**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %% [markdown]
# **training with x**

# %%
x_train
# Out:
#         district_label  pincode  demo_age_5_17  date_encoded  avg_enrollments
# 104668              53   585214              3        739537              3.0
# 68235               53   585218              1        739586              6.5
# 19019               53   585319              1        739499              3.0
# 11035               53   585355              3        739597              3.5
# 69586               53   585319              1        739589              3.5
# ...                ...      ...            ...           ...              ...
# 62886               53   585309              9        739559              9.5
# 4571                53   585290              1        739569              8.5
# 25963               53   585224              0        739545              0.5
# 7091                53   585218              0        739588              2.5
# 62117               53   585287              1        739556              3.0
#
# [1111 rows x 5 columns]

# %% [markdown]
# **testing with x**

# %%
x_test
# Out:
#         district_label  pincode  demo_age_5_17  date_encoded  avg_enrollments
# 104673              53   585309              1        739537              1.5
# 44862               53   585287              1        739611              3.5
# 27694               53   585287              0        739551              2.0
# 21269               53   585315              0        739507              1.0
# 24729               53   585220              1        739541              1.5
# ...                ...      ...            ...           ...              ...
# 39806               53   585309              4        739595              8.0
# 65950               53   585290              2        739568              6.0
# 67879               53   585319              2        739586              2.5
# 57134               53   585215              1        739543              2.5
# 55458               53   585221              1        739514              5.0
#
# [278 rows x 5 columns]

# %% [markdown]
# **traning with y**

# %%
y_train
# Out:
# 104668     3
# 68235     12
# 19019      5
# 11035      4
# 69586      6
#           ..
# 62886     10
# 4571      16
# 25963      1
# 7091       5
# 62117      5
# Name: demo_age_17_, Length: 1111, dtype: int64

# %% [markdown]
# **testing with y**

# %%
y_test
# Out:
# 104673     2
# 44862      6
# 27694      4
# 21269      2
# 24729      2
#           ..
# 39806     12
# 65950     10
# 67879      3
# 57134      4
# 55458      9
# Name: demo_age_17_, Length: 278, dtype: int64

# %% [markdown]
# # model building

# %% [markdown]
# ##linear regression

# %% [markdown]
# # Training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### applying the model

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_train_pred
# Out:
# array([ 3., 12.,  5., ...,  1.,  5.,  5.])

# %%
y_lr_test_pred
# Out:
# array([ 2.00000000e+00,  6.00000000e+00,  4.00000000e+00,  2.00000000e+00,
#         2.00000000e+00,  2.00000000e+00,  4.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.80000000e+01,  1.00000000e+00,  4.00000000e+00,
#         1.30000000e+01,  3.00000000e+00,  2.00000000e+00,  1.00000000e+00,
#         2.00000000e+00,  2.30000000e+01,  2.00000000e+00,  4.00000000e+00,
#         1.10000000e+01,  9.00000000e+00,  3.00000000e+00,  1.60000000e+01,
#         1.00000000e+01,  1.00000000e+00,  1.00000000e+00,  2.00000000e+00,
#         1.90000000e+01,  5.00000000e+00,  6.00000000e+00,  9.00000000e+00,
#         1.00000000e+00,  1.20000000e+01,  1.00000000e+01,  5.00000000e+00,
#         4.00000000e+00,  9.00000000e+00,  2.00000000e+00,  7.00000000e+00,
#         4.00000000e+00,  8.00000000e+00,  4.00000000e+00,  1.00000000e+00,
#         4.00000000e+00,  2.20000000e+01,  5.00000000e+00,  1.30000000e+01,
#         8.00000000e+00,  1.00000000e+00,  1.00000000e+00,  2.30000000e+01,
#         1.80000000e+01,  5.00000000e+00,  1.20000000e+01,  4.00000000e+00,
#         2.30000000e+01,  9.00000000e+00,  2.00000000e+01,  6.00000000e+00,
#         9.00000000e+00,  1.70000000e+01,  1.00000000e+00,  3.00000000e+00,
#         5.00000000e+01,  2.00000000e+00,  4.33000000e+02,  2.00000000e+00,
#         2.00000000e+01,  1.40000000e+01,  4.00000000e+00,  1.50000000e+01,
#         5.00000000e+00, -1.92068583e-14,  1.70000000e+01,  6.00000000e+00,
#         7.00000000e+00,  1.30000000e+01,  1.90000000e+01,  2.00000000e+00,
#         1.00000000e+01,  6.00000000e+00,  5.00000000e+00,  3.16000000e+02,
#         2.40000000e+01,  6.00000000e+00,  1.10000000e+01,  1.60000000e+01,
#         2.00000000e+00,  4.00000000e+00,  1.10000000e+01, -2.33146835e-15,
#         6.00000000e+00,  5.00000000e+00,  1.00000000e+00,  5.00000000e+00,
#         1.80000000e+01,  2.00000000e+00,  8.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  4.00000000e+00,  1.50000000e+01,  8.00000000e+00,
#         3.00000000e+00,  1.00000000e+00,  2.00000000e+01,  3.00000000e+00,
#         8.00000000e+00,  5.00000000e+00,  9.00000000e+00,  4.00000000e+00,
#         7.00000000e+00,  1.00000000e+00,  4.00000000e+00,  1.20000000e+01,
#         9.00000000e+00,  1.50000000e+01,  6.00000000e+00,  3.00000000e+00,
#         8.00000000e+00,  4.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         3.00000000e+00,  2.00000000e+00,  1.60000000e+01,  4.00000000e+00,
#         5.00000000e+00,  1.60000000e+01,  2.00000000e+00,  2.00000000e+00,
#         7.00000000e+00,  1.00000000e+01,  5.00000000e+00,  2.00000000e+00,
#         1.00000000e+01,  8.00000000e+00,  9.00000000e+00,  6.00000000e+00,
#         2.00000000e+00,  4.00000000e+00,  8.00000000e+00,  6.00000000e+00,
#         5.00000000e+00,  2.00000000e+00,  1.20000000e+01,  4.00000000e+00,
#         7.00000000e+00,  1.30000000e+01,  3.00000000e+00,  1.00000000e+00,
#         6.00000000e+00,  2.00000000e+00,  3.00000000e+00,  2.00000000e+00,
#         2.00000000e+00,  4.00000000e+00,  4.00000000e+00,  1.30000000e+01,
#        -6.43929354e-15,  5.00000000e+00,  3.00000000e+00,  1.30000000e+01,
#         2.10000000e+01,  2.00000000e+00,  1.00000000e+00,  1.50000000e+01,
#         1.20000000e+01,  1.20000000e+01,  2.00000000e+00,  1.40000000e+01,
#         3.00000000e+00,  1.40000000e+01,  1.40000000e+01,  1.60000000e+01,
#         1.40000000e+01,  1.77982629e-14,  2.80000000e+01,  1.00000000e+01,
#         2.60000000e+01,  4.00000000e+00,  5.00000000e+00,  4.00000000e+00,
#         1.40000000e+01,  8.00000000e+00,  4.00000000e+00,  3.00000000e+00,
#         4.00000000e+00,  3.00000000e+00,  5.00000000e+00,  4.00000000e+00,
#         2.00000000e+00,  1.50000000e+01,  3.00000000e+00,  2.00000000e+00,
#         4.00000000e+00,  6.00000000e+00,  1.30000000e+01,  2.10000000e+01,
#         1.90000000e+01,  2.00000000e+00,  5.00000000e+00,  2.80000000e+01,
#         1.10000000e+01,  1.00000000e+01,  1.00000000e+01,  1.10000000e+01,
#        -7.66053887e-15,  1.00000000e+00,  1.00000000e+01,  2.70000000e+01,
#         4.00000000e+00,  6.00000000e+00,  9.00000000e+00,  1.00000000e+00,
#         6.00000000e+00,  3.00000000e+00,  1.50000000e+01,  2.30000000e+01,
#         1.40000000e+01,  1.30000000e+01,  7.00000000e+00,  1.00000000e+00,
#         8.00000000e+00,  1.84000000e+02,  1.30000000e+01,  2.10000000e+01,
#         5.00000000e+00,  3.00000000e+00,  1.80000000e+01,  1.10000000e+01,
#        -6.32827124e-15,  2.80000000e+01,  9.00000000e+00,  1.40000000e+01,
#         1.00000000e+00,  9.00000000e+00,  2.80000000e+01,  1.00000000e+01,
#         5.00000000e+00,  8.00000000e+00,  3.00000000e+00,  1.40000000e+01,
#         6.00000000e+00,  1.00000000e+01,  1.00000000e+00,  8.00000000e+00,
#         1.20000000e+01,  5.00000000e+00,  5.00000000e+00,  2.20000000e+01,
#         3.00000000e+00,  8.00000000e+00,  1.70000000e+01,  1.10000000e+01,
#         5.00000000e+00,  1.40000000e+01,  9.00000000e+00,  3.00000000e+00,
#         6.00000000e+00,  1.00000000e+00,  2.00000000e+00,  1.10000000e+01,
#         1.60000000e+01,  2.50000000e+01,  3.00000000e+00,  2.00000000e+00,
#         8.00000000e+00,  2.00000000e+00,  4.00000000e+00,  8.00000000e+00,
#         3.00000000e+00,  1.20000000e+01,  1.00000000e+01,  3.00000000e+00,
#         4.00000000e+00,  9.00000000e+00])

# %% [markdown]
# # Evaluate model performance

# %%
y_train
# Out:
# 104668     3
# 68235     12
# 19019      5
# 11035      4
# 69586      6
#           ..
# 62886     10
# 4571      16
# 25963      1
# 7091       5
# 62117      5
# Name: demo_age_17_, Length: 1111, dtype: int64

# %%
from sklearn.metrics import mean_squared_error ,r2_score

lr_train_mse = mean_squared_error(y_train,y_lr_train_pred)
lr_train_r2 = r2_score(y_train,y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test,y_lr_test_pred)
lr_test_r2 = r2_score(y_test,y_lr_test_pred)

# %%
print('LR MSE(Train):' , lr_train_mse)
print("LR R2 (Train): ",lr_train_r2)
print('LR MSE(Test):' , lr_test_mse)
print("LR R2 (Test): ",lr_test_r2)
# Out:
# LR MSE(Train): 5.888557882828252e-28
# LR R2 (Train):  1.0
# LR MSE(Test): 6.178510554825478e-28
# LR R2 (Test):  1.0

# %%
lr_result = pd.DataFrame(['Linear Regression',lr_train_mse,lr_train_r2,lr_test_mse,lr_test_r2]).transpose()
lr_result.columns = ['Method','Training MSE','Training R2','Testing MSE','Testing R2']

# %%
lr_result
# Out:
#               Method Training MSE Training R2 Testing MSE Testing R2
# 0  Linear Regression          0.0         1.0         0.0        1.0

# %% [markdown]
# # Random Forest

# %% [markdown]
# **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# **Evaluate the model**

# %%
from sklearn.metrics import mean_squared_error ,r2_score

rf_train_mse = mean_squared_error(y_train,y_rf_train_pred)
rf_train_r2 = r2_score(y_train,y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test,y_rf_test_pred)
rf_test_r2 = (f'{r2_score(y_test,y_rf_test_pred):.4f}')

# %%
rf_result = pd.DataFrame(['Random Forest',rf_train_mse,rf_train_r2,rf_test_mse,rf_test_r2]).transpose()
rf_result.columns = ['Method','Training MSE','Training R2','Testing MSE','Testing R2']
rf_result
# Out:
#           Method Training MSE Training R2 Testing MSE Testing R2
# 0  Random Forest    45.940174     0.97682   72.690495     0.9362

# %% [markdown]
# **ADDING XGBOOST MODEL**

# %% [markdown]
# **for better performance result**

# %%
from xgboost import XGBRegressor
XGB = XGBRegressor(
    max_depth=2,
    random_state=100
)
XGB.fit(x_train, y_train)
print("XGBoost training complete!")
# Out:
# XGBoost training complete!

# %%
y_xgb_train_pred = XGB.predict(x_train)
y_xgb_test_pred = XGB.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error ,r2_score

xgb_train_mse = mean_squared_error(y_train,y_xgb_train_pred)
xgb_train_r2 = r2_score(y_train,y_xgb_train_pred)

xgb_test_mse = mean_squared_error(y_test,y_xgb_test_pred)
xgb_test_r2 = (f'{r2_score(y_test,y_xgb_test_pred):.4f}')

# %% [markdown]
# **final Evaluation**

# %%
xgb_result = pd.DataFrame(['XGBoost',xgb_train_mse,xgb_train_r2,xgb_test_mse,xgb_test_r2]).transpose()
xgb_result.columns = ['Method','Training MSE','Training R2','Testing MSE','Testing R2']
xgb_result
# Out:
#     Method Training MSE Training R2 Testing MSE Testing R2
# 0  XGBoost     0.101974    0.999949   64.854881     0.9431

# %% [markdown]
# # MODEL COMPARISION

# %%
final_df_model = pd.concat([lr_result,rf_result,xgb_result],axis=0)
final_df_model.columns = ['Methods','Training MSE','Training R2','Testing MSE','Testing R2']
final_df_model
final_df_model.reset_index(drop=True)
# Out:
#              Methods Training MSE Training R2 Testing MSE Testing R2
# 0  Linear Regression          0.0         1.0         0.0        1.0
# 1      Random Forest    45.940174     0.97682   72.690495     0.9362
# 2            XGBoost     0.101974    0.999949   64.854881     0.9431

# %% [markdown]
# # Data visualization of Prediction results

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.scatter(x=y_train, y=y_xgb_train_pred,alpha=0.5)
plt.plot()
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('XGBOOST REGRESSION')
plt.show()
